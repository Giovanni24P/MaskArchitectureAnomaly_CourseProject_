# %%
# !git clone https://github.com/Giovanni24P/MaskArchitectureAnomaly_CourseProject_.git

from google.colab import drive
drive.mount('/content/drive')
# Out:
# fatal: destination path 'MaskArchitectureAnomaly_CourseProject_' already exists and is not an empty directory.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd  MaskArchitectureAnomaly_CourseProject_/eomt

# !pip install -r "requirements.txt"
# Out:
# /content/MaskArchitectureAnomaly_CourseProject_/eomt
# Collecting gitignore_parser==0.1.12 (from -r requirements.txt (line 1))
#   Downloading gitignore_parser-0.1.12.tar.gz (5.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jsonargparse==4.38 (from jsonargparse[signatures]==4.38->-r requirements.txt (line 2))
#   Downloading jsonargparse-4.38.0-py3-none-any.whl.metadata (12 kB)
# Collecting matplotlib==3.10.1 (from -r requirements.txt (line 3))
#   Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting timm==1.0.15 (from -r requirements.txt (line 4))
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.6 MB/s eta 0:00:00
# Collecting lightning==2.5.1.post0 (from -r requirements.txt (line 5))
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Collecting transformers==4.56.1 (from -r requirements.txt (line 6))
#   Downloading transformers-4.56.1-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.3 MB/s eta 0:00:00
# Collecting scipy==1.15.2 (from -r requirements.txt (line 7))
#   Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.6 MB/s eta 0:00:00
# Collecting torch==2.7.0 (from -r requirements.txt (line 8))
#   Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision==0.22.0 (from -r requirements.txt (line 9))
#   Downloading torchvision-0.22.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting ipykernel==6.29.5 (from -r requirements.txt (line 10))
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting fvcore==0.1.5.post20221221 (from -r requirements.txt (line 11))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting torchmetrics==1.7.1 (from -r requirements.txt (line 12))
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting pycocotools==2.0.8 (from -r requirements.txt (line 13))
#   Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.12/dist-packages (from jsonargparse==4.38->jsonargparse[signatures]==4.38->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm==1.0.15->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm==1.0.15->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning==2.5.1.post0->-r requirements.txt (line 5))
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting packaging>=20.0 (from matplotlib==3.10.1->-r requirements.txt (line 3))
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.1.post0->-r requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.1.post0->-r requirements.txt (line 5)) (4.15.0)
# Collecting pytorch-lightning (from lightning==2.5.1.post0->-r requirements.txt (line 5))
#   Downloading pytorch_lightning-2.6.5-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.1->-r requirements.txt (line 6)) (3.29.0)
# Collecting huggingface_hub (from timm==1.0.15->-r requirements.txt (line 4))
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.1->-r requirements.txt (line 6)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.1->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.1->-r requirements.txt (line 6)) (0.22.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.7.0->-r requirements.txt (line 8)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.0->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.7.0->-r requirements.txt (line 8)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.0->-r requirements.txt (line 8)) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch==2.7.0->-r requirements.txt (line 8))
#   Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting comm>=0.1.1 (from ipykernel==6.29.5->-r requirements.txt (line 10))
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 10)) (5.7.1)
# Collecting yacs>=0.1.6 (from fvcore==0.1.5.post20221221->-r requirements.txt (line 11))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore==0.1.5.post20221221->-r requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore==0.1.5.post20221221->-r requirements.txt (line 11)) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore==0.1.5.post20221221->-r requirements.txt (line 11))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]==4.38->-r requirements.txt (line 2)) (0.18.0)
# Collecting typeshed-client>=2.1.0 (from jsonargparse[signatures]==4.38->-r requirements.txt (line 2))
#   Downloading typeshed_client-2.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (3.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm==1.0.15->-r requirements.txt (line 4)) (1.5.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore==0.1.5.post20221221->-r requirements.txt (line 11))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel==6.29.5->-r requirements.txt (line 10)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.29.5->-r requirements.txt (line 10)) (4.10.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.1->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.7.0->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]==4.38->-r requirements.txt (line 2)) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.7.0->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.1->-r requirements.txt (line 6)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.1->-r requirements.txt (line 6)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.1->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.1->-r requirements.txt (line 6)) (2026.5.20)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 5)) (1.24.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 10)) (0.7.0)
# Downloading jsonargparse-4.38.0-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 15.3 MB/s eta 0:00:00
# Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 101.9 MB/s eta 0:00:00
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 95.7 MB/s eta 0:00:00
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 54.9 MB/s eta 0:00:00
# Downloading transformers-4.56.1-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 72.9 MB/s eta 0:00:00
# Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 21.5 MB/s eta 0:00:00
# Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (865.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 MB 1.5 MB/s eta 0:00:00
# Downloading torchvision-0.22.0-cp312-cp312-manylinux_2_28_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 24.0 MB/s eta 0:00:00
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 13.6 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 53.1 MB/s eta 0:00:00
# Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.5/443.5 kB 38.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 108.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 71.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 52.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 66.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 6.2 MB/s eta 0:00:00
# Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 7.0 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 32.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.5 MB/s eta 0:00:00
# Downloading typeshed_client-2.12.0-py3-none-any.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 45.9 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading pytorch_lightning-2.6.5-py3-none-any.whl (852 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 36.6 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 126.6 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: gitignore_parser, fvcore, iopath
#   Building wheel for gitignore_parser (pyproject.toml) ... done
#   Created wheel for gitignore_parser: filename=gitignore_parser-0.1.12-py3-none-any.whl size=5054 sha256=ed46c338c82d4e1ccecb3dff724aa17f19a63511d00a63957f8924857eee138d
#   Stored in directory: /root/.cache/pip/wheels/2e/1e/fd/5f54a9fb2812e64c709303dab7d79ef5e74a655a0dcad67b91
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=78a99af8a447dd28f71c691850828472bd6e14b26573a3e1d3361cad96b44f53
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=83295cc744e9200fabf142d6e8776f285b20d53f8182a5f4745d1d64c34e87fe
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built gitignore_parser fvcore iopath
# Installing collected packages: nvidia-cusparselt-cu12, gitignore_parser, yacs, typeshed-client, triton, scipy, portalocker, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jsonargparse, jedi, comm, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, matplotlib, lightning-utilities, iopath, huggingface_hub, pycocotools, nvidia-cusolver-cu12, ipykernel, fvcore, transformers, torch, torchvision, torchmetrics, timm, pytorch-lightning, lightning
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.2
#     Uninstalling packaging-26.2:
#       Successfully uninstalled packaging-26.2
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.9
#     Uninstalling nvidia-nccl-cu12-2.28.9:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.9
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.13.1.3
#     Uninstalling nvidia-cufile-cu12-1.13.1.3:
#       Successfully uninstalled nvidia-cufile-cu12-1.13.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.19.0.56
#     Uninstalling nvidia-cudnn-cu12-9.19.0.56:
#       Successfully uninstalled nvidia-cudnn-cu12-9.19.0.56
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.17.0
#     Uninstalling huggingface_hub-1.17.0:
#       Successfully uninstalled huggingface_hub-1.17.0
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.11
#     Uninstalling pycocotools-2.0.11:
#       Successfully uninstalled pycocotools-2.0.11
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.9.0
#     Uninstalling transformers-5.9.0:
#       Successfully uninstalled transformers-5.9.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu128
#     Uninstalling torch-2.11.0+cu128:
#       Successfully uninstalled torch-2.11.0+cu128
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.26.0+cu128
#     Uninstalling torchvision-0.26.0+cu128:
#       Successfully uninstalled torchvision-0.26.0+cu128
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.27
#     Uninstalling timm-1.0.27:
#       Successfully uninstalled timm-1.0.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.5 which is incompatible.
# Successfully installed comm-0.2.3 fvcore-0.1.5.post20221221 gitignore_parser-0.1.12 huggingface_hub-0.36.2 iopath-0.1.10 ipykernel-6.29.5 jedi-0.20.0 jsonargparse-4.38.0 lightning-2.5.1.post0 lightning-utilities-0.15.3 matplotlib-3.10.1 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-24.2 portalocker-3.2.0 pycocotools-2.0.8 pytorch-lightning-2.6.5 scipy-1.15.2 timm-1.0.15 torch-2.7.0 torchmetrics-1.7.1 torchvision-0.22.0 transformers-4.56.1 triton-3.3.0 typeshed-client-2.12.0 yacs-0.1.8

# %% [markdown]
# © 2025 Mobile Perception Systems Lab at TU/e. All rights reserved. Licensed under the MIT License.

# %% [markdown]
# ## Setup

# %%
import yaml
from lightning import seed_everything
import torch
from torch.nn import functional as F
from torch.amp.autocast_mode import autocast
import matplotlib.pyplot as plt
import numpy as np
from huggingface_hub import hf_hub_download
from huggingface_hub.utils import RepositoryNotFoundError
import warnings
import importlib

seed_everything(0, verbose=False)

device = 0  # TODO: change to the GPU you want to use
img_idx = 4  # TODO: change to the index of the image you want to visualize
config_path = "/content/MaskArchitectureAnomaly_CourseProject_/eomt/configs/dinov2/coco/panoptic/eomt_base_640_2x.yaml"  # TODO: change to the config file
data_path = "/content/drive/MyDrive/cityscapes/datasets"  # TODO: change to the dataset directory

with open(config_path, "r") as f:
    config = yaml.safe_load(f)


def create_mapping(images, ignore_index):
    unique_ids = np.unique(np.concatenate([np.unique(img) for img in images]))
    valid_ids = unique_ids[unique_ids != ignore_index]
    colors = np.array(
        [plt.cm.hsv(i / len(valid_ids))[:3] for i in range(len(valid_ids))]
    )
    mapping = {cid: colors[i] for i, cid in enumerate(valid_ids)}
    mapping[ignore_index] = np.array([0, 0, 0])
    return mapping


def apply_colormap(image, mapping):
    colored_image = np.zeros((*image.shape, 3))
    for cid in np.unique(image):
        colored_image[image == cid] = mapping.get(cid, [0, 0, 0])
    return colored_image

# %% [markdown]
# ## Load dataset
#
# Ensure the dataset files are correctly prepared and placed in the folder specified by `data_path`.

# %%
data_module_name, class_name = config["data"]["class_path"].rsplit(".", 1)
data_module = getattr(importlib.import_module(data_module_name), class_name)
data_module_kwargs = config["data"].get("init_args", {})

data = data_module(
    path=data_path,
    batch_size=1,
    num_workers=0,
    check_empty_targets=False,
    **data_module_kwargs
).setup()

# %% [markdown]
# ## Load model

# %%
warnings.filterwarnings(
    "ignore",
    message=r".*Attribute 'network' is an instance of `nn\.Module` and is already saved during checkpointing.*",
)

# Load encoder
encoder_cfg = config["model"]["init_args"]["network"]["init_args"]["encoder"]
encoder_module_name, encoder_class_name = encoder_cfg["class_path"].rsplit(".", 1)
encoder_cls = getattr(importlib.import_module(encoder_module_name), encoder_class_name)
encoder = encoder_cls(img_size=data.img_size, **encoder_cfg.get("init_args", {}))

# Load network
network_cfg = config["model"]["init_args"]["network"]
network_module_name, network_class_name = network_cfg["class_path"].rsplit(".", 1)
network_cls = getattr(importlib.import_module(network_module_name), network_class_name)
network_kwargs = {k: v for k, v in network_cfg["init_args"].items() if k != "encoder"}
network = network_cls(
    masked_attn_enabled=False,
    num_classes=data.num_classes,
    encoder=encoder,
    **network_kwargs,
)

# Load Lightning module
lit_module_name, lit_class_name = config["model"]["class_path"].rsplit(".", 1)
lit_cls = getattr(importlib.import_module(lit_module_name), lit_class_name)
model_kwargs = {k: v for k, v in config["model"]["init_args"].items() if k != "network"}
if "stuff_classes" in config["data"].get("init_args", {}):
    model_kwargs["stuff_classes"] = config["data"]["init_args"]["stuff_classes"]

model = (
    lit_cls(
        img_size=data.img_size,
        num_classes=data.num_classes,
        network=network,
        **model_kwargs,
    )
    .eval()
    .to(device)
)

# %% [markdown]
# ## Load pre-trained weights from Hugging Face Hub
# The model weights are downloaded from the Hugging Face Hub using the logger name from the config. Make sure you have a working internet connection.

# %%
name = config.get("trainer", {}).get("logger", {}).get("init_args", {}).get("name")

if name is None:
    warnings.warn("No logger name found in the config. Please specify a model name.")
else:
    try:
        state_dict_path = hf_hub_download(
            repo_id=f"tue-mps/{name}",
            filename="pytorch_model.bin",
        )

        is_dinov3 = "dinov3" in name

        if is_dinov3:
            model_kwargs["ckpt_path"] = state_dict_path
            model_kwargs["delta_weights"] = True

        model = (
            lit_cls(
                img_size=data.img_size,
                num_classes=data.num_classes,
                network=network,
                **model_kwargs,
            )
            .eval()
            .to(device)
        )

        if not is_dinov3:
            state_dict = torch.load(
                state_dict_path, map_location=f"cuda:{device}", weights_only=True
            )
            model.load_state_dict(state_dict, strict=False)

    except RepositoryNotFoundError:
        warnings.warn(
            f"Pre-trained model not found for `{name}`. Please load your own checkpoint."
        )
# Out:
# /tmp/ipykernel_1612/344897083.py:36: UserWarning: Pre-trained model not found for `coco_panoptic_eomt_base_640`. Please load your own checkpoint.
#   warnings.warn(

# %%
### ADDED: load eomt_cityscaoes.bin and eomt_coco.bin from the drive
state_dict_path = "/content/drive/MyDrive/CourseProjectAnomaly/eomt_coco.bin"

# Recreate the model
model = (
    lit_cls(
        img_size=data.img_size,
        num_classes=data.num_classes,
        network=network,
        **model_kwargs,
    )
    .eval()
    .to(f"cuda:{device}")
)

# Load local COCO panoptic weights
state_dict = torch.load(state_dict_path, map_location="cpu", weights_only=True)

# Support both plain .bin state_dicts and Lightning-style checkpoints
if isinstance(state_dict, dict) and "state_dict" in state_dict:
    state_dict = state_dict["state_dict"]

# Optional cleanup used by this repo
state_dict = {
    k.replace("._orig_mod", ""): v
    for k, v in state_dict.items()
    if "criterion.empty_weight" not in k
}

missing, unexpected = model.load_state_dict(state_dict, strict=False)

print(f"Loaded weights from: {state_dict_path}")
print(f"Missing keys: {len(missing)}")
print(f"Unexpected keys: {len(unexpected)}")
print(missing)
print(unexpected)
# Out:
# Loaded weights from: /content/drive/MyDrive/CourseProjectAnomaly/eomt_coco.bin
# Missing keys: 1
# Unexpected keys: 0
# ['criterion.empty_weight']
# []

# %% [markdown]
# ## Semantic inference (pixel-wise classification)
#
# > This inference method also works when applied to a model trained for panoptic segmentation.
#
# Semantic inference computes per-pixel class scores by combining mask and class predictions:
#
# $$
# \sum_i p_i(c) \cdot m_i[h, w]
# $$
#
# Here, $p_i(c)$ is the class probability for class $c$ (excluding "no object"), and $m_i[h, w]$ is the sigmoid-normalized mask value for query $i$ at pixel $(h, w)$. The final class is selected by taking the argmax over classes.
#
# *This inference method was originally introduced in MaskFormer.*

# %%
IGNORE_INDEX = 255


def infer_semantic(img, target):
    with torch.no_grad(), autocast(dtype=torch.float16, device_type="cuda"):
        imgs = [img.to(device)]
        img_sizes = [img.shape[-2:] for img in imgs]
        crops, origins = model.window_imgs_semantic(imgs)

        mask_logits_per_layer, class_logits_per_layer = model(crops)
        mask_logits = F.interpolate(
            mask_logits_per_layer[-1], data.img_size, mode="bilinear"
        )

        crop_logits = model.to_per_pixel_logits_semantic(
            mask_logits, class_logits_per_layer[-1]
        )
        logits = model.revert_window_logits_semantic(crop_logits, origins, img_sizes)
        preds = logits[0].argmax(0).cpu()

    pred_array = preds.numpy()
    target_array = model.to_per_pixel_targets_semantic([target], IGNORE_INDEX)[
        0
    ].numpy()
    return pred_array, target_array


def plot_semantic_results(img, pred_array, target_array):
    mapping = create_mapping([pred_array, target_array], IGNORE_INDEX)

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(img.permute(1, 2, 0).cpu().numpy())
    axes[0].set_title("Image")
    axes[1].imshow(apply_colormap(pred_array, mapping))
    axes[1].set_title("Prediction")
    axes[2].imshow(apply_colormap(target_array, mapping))
    axes[2].set_title("Target")

    for ax in axes:
        ax.axis("off")

    plt.tight_layout()
    plt.show()


img, target = data.val_dataloader().dataset[img_idx]
pred_array, target_array = infer_semantic(img, target)
plot_semantic_results(img, pred_array, target_array)

# %% [markdown]
# ## Panoptic inference (segmentation with instance IDs)
#
# > This inference method also works when applied to a model trained for instance segmentation.
#
# Panoptic inference assigns each pixel $[h, w]$ to the query $i$ that maximizes the product of class and mask confidence:
#
# $$
# p_i(c_i) \cdot m_i[h, w]
# $$
#
# where $c_i = \arg\max_c \, p_i(c)$ is the most likely class for query $i$. A pixel is assigned to a query only if both the class confidence and mask confidence are high. Pixels assigned to the same query form a segment labeled with $c_i$. "Stuff" segments with the same class are merged; "thing" segments are kept distinct using the query index. Low-confidence and heavily occluded predictions are filtered out.
#
# *This inference method was originally introduced in MaskFormer.*

# %%
def infer_panoptic(img, target):
    with torch.no_grad(), autocast(dtype=torch.float16, device_type="cuda"):
        imgs = [img.to(device)]
        img_sizes = [img.shape[-2:] for img in imgs]

        transformed_imgs = model.resize_and_pad_imgs_instance_panoptic(imgs)
        mask_logits_per_layer, class_logits_per_layer = model(transformed_imgs)
        mask_logits = F.interpolate(
            mask_logits_per_layer[-1], model.img_size, mode="bilinear"
        )
        mask_logits = model.revert_resize_and_pad_logits_instance_panoptic(
            mask_logits, img_sizes
        )

        preds = model.to_per_pixel_preds_panoptic(
            mask_logits,
            class_logits_per_layer[-1],
            model.stuff_classes,
            model.mask_thresh,
            model.overlap_thresh,
        )[0].cpu()

    pred = preds.numpy()
    sem_pred, inst_pred = pred[..., 0], pred[..., 1]

    target_seg = model.to_per_pixel_targets_panoptic([target])[0].cpu().numpy()
    sem_target, inst_target = target_seg[..., 0], target_seg[..., 1]

    return sem_pred, inst_pred, sem_target, inst_target


def draw_black_border(sem, inst, mapping):
    h, w = sem.shape
    out = np.zeros((h, w, 3))
    for s in np.unique(sem):
        out[sem == s] = mapping[s]

    combined = sem.astype(np.int64) * 100000 + inst.astype(np.int64)
    border = np.zeros((h, w), dtype=bool)
    border[1:, :] |= combined[1:, :] != combined[:-1, :]
    border[:-1, :] |= combined[1:, :] != combined[:-1, :]
    border[:, 1:] |= combined[:, 1:] != combined[:, :-1]
    border[:, :-1] |= combined[:, 1:] != combined[:, :-1]
    out[border] = 0
    return out


def plot_panoptic_results(img, sem_pred, inst_pred, sem_target, inst_target):
    all_ids = np.union1d(np.unique(sem_pred), np.unique(sem_target))
    mapping = {
        s: (
            [0, 0, 0]
            if s == -1 or s == model.num_classes
            else plt.cm.hsv(i / len(all_ids))[:3]
        )
        for i, s in enumerate(all_ids)
    }

    vis_pred = draw_black_border(sem_pred, inst_pred, mapping)
    vis_target = draw_black_border(sem_target, inst_target, mapping)

    img_np = (
        img.cpu().numpy().transpose(1, 2, 0) if img.dim() == 3 else img.cpu().numpy()
    )

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(img_np)
    axes[0].set_title("Input")
    axes[1].imshow(vis_pred)
    axes[1].set_title("Prediction")
    axes[2].imshow(vis_target)
    axes[2].set_title("Target")

    for ax in axes:
        ax.axis("off")

    plt.tight_layout()
    plt.show()


img, target = data.val_dataloader().dataset[img_idx]
sem_pred, inst_pred, sem_target, inst_target = infer_panoptic(img, target)

# Map COCO prediction indexes to Cityscapes train IDs
sem_pred = model.coco_to_cityscapes[
    torch.as_tensor(sem_pred).clamp_min(0).long()
].cpu().numpy()

plot_panoptic_results(img, sem_pred, inst_pred, sem_target, inst_target)

print("Prediction ids:", np.unique(sem_pred))
print("Target ids:", np.unique(sem_target))
# Out:
# Prediction ids: [ 0  1  2  8 10 11 13 14 18 19]
# Target ids: [-1  0  1  2  5  6  7  8 10 11 12 13 14 18]
